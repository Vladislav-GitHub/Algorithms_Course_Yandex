# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
# /tmp/ipykernel_33406/143381672.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
# /tmp/ipykernel_33406/3242586923.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %% [markdown]
# # Training and Evaluation of a model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %% [markdown]
# Normalize the inputs

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %% [markdown]
# We are using Naïve Bayes algorithm

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# ~74% accuracy

# %% [markdown]
# # Using neural network

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
# Out:
# 2023-01-31 01:46:26.816195: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 01:46:29.539463: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 01:46:29.539790: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.add(Dense(5, kernel_initializer='uniform', activation='relu', input_dim=5))
model.add(Dense(5, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 3ms/step - loss: 0.6924 - accuracy: 0.5897
# Epoch 2/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.5957
# Epoch 5/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6703 - accuracy: 0.7261
# Epoch 6/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6527 - accuracy: 0.7548
# Epoch 7/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6292 - accuracy: 0.7679
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6015 - accuracy: 0.7656
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5737 - accuracy: 0.7656
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5471 - accuracy: 0.7715
# Epoch 11/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.7703
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5097 - accuracy: 0.7751
# Epoch 13/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7763
# Epoch 14/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4879 - accuracy: 0.7787
# Epoch 15/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.7739
# Epoch 16/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.7787
# Epoch 17/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4727 - accuracy: 0.7799
# Epoch 18/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4701 - accuracy: 0.7823
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.7835
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7823
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4646 - accuracy: 0.7811
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.7847
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7847
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.7847
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.7847
# Epoch 26/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7895
# Epoch 27/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4571 - accuracy: 0.7859
# Epoch 28/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4565 - accuracy: 0.7859
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4559 - accuracy: 0.7883
# Epoch 30/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4549 - accuracy: 0.7883
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7883
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4536 - accuracy: 0.7847
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.7835
# Epoch 34/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7883
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.7847
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.7883
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.7907
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.7931
# Epoch 39/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7883
# Epoch 40/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4501 - accuracy: 0.7871
# Epoch 41/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7919
# Epoch 42/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7943
# Epoch 43/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4491 - accuracy: 0.7943
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7955
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4489 - accuracy: 0.7883
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4481 - accuracy: 0.7943
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.7955
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7919
# Epoch 49/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4475 - accuracy: 0.7943
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.7895

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 6ms/step
# 0.784688995215311

# %% [markdown]
# ~78% accuracy
